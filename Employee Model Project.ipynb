# %% [markdown]
# # EMPLOYEE ATTRITION CONTROL

# %% [markdown]
# ### CASE STUDY
# The project is to help a company which is trying to control attrition. There are two sets of data: "Existing employees" and "Employees who have left". Following attributes are available for every employee;
# -Satisfaction Level
# -Last evaluation
# -Number of projects
# -Average monthly hours
# -Time spent at the company
# -Whether they have had a work accident
# -Whether they have had a promotion in the last 5 years
# -Departments (column sales)
# -Salary
#
# Use your analytics skills to answer the following questions :
# 1. What type of employees are leaving?
# 2. Which employees are prone to leave next.
# 3. Recommendations

# %% [markdown]
# # DATA EXPLORATION

# %%
import numpy as np
import pandas as pd

# %%
train = pd.read_csv(r"C:\Users\DELL\Documents\train.csv")
test = pd.read_csv(r"C:\Users\DELL\Documents\test2.csv")

# %%
train.head()
# Out:
#    Emp ID  satisfaction_level  last_evaluation  number_project  \
# 0       1                0.58             0.74               4
# 1       4                0.78             0.82               5
# 2       5                0.49             0.60               3
# 3       6                0.36             0.95               3
# 4       7                0.54             0.37               2
#
#    average_montly_hours  Work_accident  promotion_last_5years   dept salary  \
# 0                   215              0                      0  sales    low
# 1                   247              0                      0  sales    low
# 2                   214              0                      0  sales    low
# 3                   206              0                      0  sales    low
# 4                   176              0                      0  sales    low
#
#    Status  YearOfRecruitment
# 0       0               2016
# 1       0               2016
# 2       0               2017
# 3       0               2015
# 4       0               2017

# %%
test.head()
# Out:
#    Emp ID  satisfaction_level  last_evaluation  number_project  \
# 0       2                0.82             0.67               2
# 1       3                0.45             0.69               5
# 2       8                0.99             0.91               5
# 3      10                0.74             0.64               4
# 4      13                0.48             0.94               5
#
#    average_montly_hours  Work_accident  promotion_last_5years        dept  \
# 0                   202              0                      0       sales
# 1                   193              0                      0       sales
# 2                   136              0                      0       sales
# 3                   268              0                      0       sales
# 4                   255              0                      0  accounting
#
#    salary  YearOfRecruitment
# 0     low               2016
# 1     low               2016
# 2     low               2015
# 3     low               2016
# 4  medium               2013

# %%
train.isnull().mean()
# Out:
# Emp ID                   0.0
# satisfaction_level       0.0
# last_evaluation          0.0
# number_project           0.0
# average_montly_hours     0.0
# Work_accident            0.0
# promotion_last_5years    0.0
# dept                     0.0
# salary                   0.0
# Status                   0.0
# YearOfRecruitment        0.0
# dtype: float64

# %%
test.isnull().mean()
# Out:
# Emp ID                   0.0
# satisfaction_level       0.0
# last_evaluation          0.0
# number_project           0.0
# average_montly_hours     0.0
# Work_accident            0.0
# promotion_last_5years    0.0
# dept                     0.0
# salary                   0.0
# YearOfRecruitment        0.0
# dtype: float64

# %%
train.drop(['dept'], axis=1, inplace=True)
test.drop(['dept'], axis=1, inplace=True)

# %%
train.head()
# Out:
#    Emp ID  satisfaction_level  last_evaluation  number_project  \
# 0       1                0.58             0.74               4
# 1       4                0.78             0.82               5
# 2       5                0.49             0.60               3
# 3       6                0.36             0.95               3
# 4       7                0.54             0.37               2
#
#    average_montly_hours  Work_accident  promotion_last_5years salary  Status  \
# 0                   215              0                      0    low       0
# 1                   247              0                      0    low       0
# 2                   214              0                      0    low       0
# 3                   206              0                      0    low       0
# 4                   176              0                      0    low       0
#
#    YearOfRecruitment
# 0               2016
# 1               2016
# 2               2017
# 3               2015
# 4               2017

# %%
test.head()
# Out:
#    Emp ID  satisfaction_level  last_evaluation  number_project  \
# 0       2                0.82             0.67               2
# 1       3                0.45             0.69               5
# 2       8                0.99             0.91               5
# 3      10                0.74             0.64               4
# 4      13                0.48             0.94               5
#
#    average_montly_hours  Work_accident  promotion_last_5years  salary  \
# 0                   202              0                      0     low
# 1                   193              0                      0     low
# 2                   136              0                      0     low
# 3                   268              0                      0     low
# 4                   255              0                      0  medium
#
#    YearOfRecruitment
# 0               2016
# 1               2016
# 2               2015
# 3               2016
# 4               2013

# %%
column = ['salary']
train=pd.get_dummies(train, columns=column, drop_first=True)
test=pd.get_dummies(test,columns=column, drop_first=True)

# %%
train.head()
# Out:
#    Emp ID  satisfaction_level  last_evaluation  number_project  \
# 0       1                0.58             0.74               4
# 1       4                0.78             0.82               5
# 2       5                0.49             0.60               3
# 3       6                0.36             0.95               3
# 4       7                0.54             0.37               2
#
#    average_montly_hours  Work_accident  promotion_last_5years  Status  \
# 0                   215              0                      0       0
# 1                   247              0                      0       0
# 2                   214              0                      0       0
# 3                   206              0                      0       0
# 4                   176              0                      0       0
#
#    YearOfRecruitment  salary_low  salary_medium
# 0               2016           1              0
# 1               2016           1              0
# 2               2017           1              0
# 3               2015           1              0
# 4               2017           1              0

# %%
test.head()
# Out:
#    Emp ID  satisfaction_level  last_evaluation  number_project  \
# 0       2                0.82             0.67               2
# 1       3                0.45             0.69               5
# 2       8                0.99             0.91               5
# 3      10                0.74             0.64               4
# 4      13                0.48             0.94               5
#
#    average_montly_hours  Work_accident  promotion_last_5years  \
# 0                   202              0                      0
# 1                   193              0                      0
# 2                   136              0                      0
# 3                   268              0                      0
# 4                   255              0                      0
#
#    YearOfRecruitment  salary_low  salary_medium
# 0               2016           1              0
# 1               2016           1              0
# 2               2015           1              0
# 3               2016           1              0
# 4               2013           0              1

# %% [markdown]
# # DATA MODELLING

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.model_selection import train_test_split

# %%
X = train.drop(['Status'], axis=1)
y = train['Status']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state=42)

# %%
log = LogisticRegression()

# %%
log.fit(X_train, y_train)
# Out:
# C:\Users\DELL\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=None, solver='warn', tol=0.0001, verbose=0,
#                    warm_start=False)

# %% [markdown]
# # DATA PREDICTION

# %%
prediction = log.predict(X_test)

# %%
accuracy_score(prediction, y_test)
# Out:
# 0.9987361769352291

# %%
confusion_matrix(prediction, y_test)
# Out:
# array([[2427,    3],
#        [   1,  734]], dtype=int64)

# %%
id = test['Emp ID']

# %%
id.head(30)
# Out:
# 0      2
# 1      3
# 2      8
# 3     10
# 4     13
# 5     17
# 6     18
# 7     19
# 8     23
# 9     29
# 10    36
# 11    39
# 12    40
# 13    42
# 14    45
# 15    46
# 16    50
# 17    51
# 18    54
# 19    55
# 20    58
# 21    59
# 22    64
# 23    68
# 24    71
# 25    74
# 26    75
# 27    76
# 28    77
# 29    78
# Name: Emp ID, dtype: int64

# %%
final_prediction = log.predict(test)

# %%
final_prediction.shape
# Out:
# (4450,)

# %%
submission = pd.DataFrame({'Emp ID':id, 'Status':final_prediction})

# %%
submission.to_csv('Employee Model', index = False)

# %%
submission
# Out:
#       Emp ID  Status
# 0          2       0
# 1          3       0
# 2          8       0
# 3         10       0
# 4         13       0
# 5         17       0
# 6         18       0
# 7         19       0
# 8         23       0
# 9         29       0
# 10        36       0
# 11        39       0
# 12        40       0
# 13        42       0
# 14        45       0
# 15        46       0
# 16        50       0
# 17        51       0
# 18        54       0
# 19        55       0
# 20        58       0
# 21        59       0
# 22        64       0
# 23        68       0
# 24        71       0
# 25        74       0
# 26        75       0
# 27        76       0
# 28        77       0
# 29        78       0
# ...      ...     ...
# 4420   14918       1
# 4421   14920       1
# 4422   14921       1
# 4423   14923       1
# 4424   14927       1
# 4425   14929       1
# 4426   14930       1
# 4427   14931       1
# 4428   14932       1
# 4429   14935       1
# 4430   14937       1
# 4431   14939       1
# 4432   14943       1
# 4433   14948       1
# 4434   14951       1
# 4435   14958       1
# 4436   14960       1
# 4437   14961       1
# 4438   14972       1
# 4439   14980       1
# 4440   14981       1
# 4441   14982       1
# 4442   14983       1
# 4443   14984       1
# 4444   14986       1
# 4445   14991       1
# 4446   14992       1
# 4447   14993       1
# 4448   14998       1
# 4449   14999       1
#
# [4450 rows x 2 columns]

# %% [markdown]
# # Conclusion

# %% [markdown]
# In this emplyee attrition control model, we have seen that many of the employees of the company will leave because they have  not been promoted for the past 5years.

# %% [markdown]
# # Recommendation

# %% [markdown]
# The company should endeavour to promote their employees to avoid the employees leaving the company
